# %% [markdown]
# # Example Data Science Notebook
# ## Yahoo Financial Data analyzed with Pandas

# %%
# Install 'pandas_datareader' Library. https://pandas-datareader.readthedocs.io/en/latest/
# !pip install pandas_datareader

# %%
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import pandas as pd
import datetime as dt
import yfinance as yfin

# %%
start = dt.datetime(2009, 1, 1)
end = dt.datetime(2018, 12, 31)
tickers = ['GOOG', 'AAPL', '^DJI', '^GSPC']

yfin.pdr_override()

all_tickers = pdr.get_data_yahoo(tickers, start=start, end=end)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
all_tickers
# Out:
#             Adj Close                                            Close
#                  AAPL       GOOG          ^DJI        ^GSPC       AAPL
# Date
# 2009-01-02   2.754724   8.003003   9034.690430   931.799988   3.241071  \
# 2009-01-05   2.870985   8.170624   8952.889648   927.450012   3.377857
# 2009-01-06   2.823632   8.320313   9015.099609   934.700012   3.322143
# 2009-01-07   2.762618   8.020188   8769.700195   906.650024   3.250357
# 2009-01-08   2.813917   8.099391   8742.459961   909.729980   3.310714
# ...               ...        ...           ...          ...        ...
# 2018-12-21  36.264633  48.977001  22445.369141  2416.620117  37.682499
# 2018-12-24  35.326313  48.811001  21792.199219  2351.100098  36.707500
# 2018-12-26  37.814049  51.973000  22878.449219  2467.699951  39.292500
# 2018-12-27  37.568642  52.194000  23138.820312  2488.830078  39.037498
# 2018-12-28  37.587887  51.854000  23062.400391  2485.739990  39.057499
#
#                                                        High             ...
#                  GOOG          ^DJI        ^GSPC       AAPL       GOOG  ...
# Date                                                                    ...
# 2009-01-02   8.003003   9034.690430   931.799988   3.251429   8.015456  ...  \
# 2009-01-05   8.170624   8952.889648   927.450012   3.435000   8.250077  ...
# 2009-01-06   8.320313   9015.099609   934.700012   3.470357   8.488184  ...
# 2009-01-07   8.020188   8769.700195   906.650024   3.303571   8.241857  ...
# 2009-01-08   8.099391   8742.459961   909.729980   3.326786   8.099391  ...
# ...               ...           ...          ...        ...        ...  ...
# 2018-12-21  48.977001  22445.369141  2416.620117  39.540001  51.201000  ...
# 2018-12-24  48.811001  21792.199219  2351.100098  37.887501  50.176998  ...
# 2018-12-26  51.973000  22878.449219  2467.699951  39.307499  52.000000  ...
# 2018-12-27  52.194000  23138.820312  2488.830078  39.192501  52.194500  ...
# 2018-12-28  51.854000  23062.400391  2485.739990  39.630001  52.778000  ...
#
#                      Low                    Open
#                     ^DJI        ^GSPC       AAPL       GOOG          ^DJI
# Date
# 2009-01-02   8760.780273   899.349976   3.067143   7.686190   8772.250000  \
# 2009-01-05   8892.360352   919.530029   3.327500   7.995033   9027.129883
# 2009-01-06   8940.950195   927.280029   3.426786   8.293414   8954.570312
# 2009-01-07   8719.919922   902.369995   3.278929   8.177349   8996.940430
# 2009-01-08   8651.190430   896.809998   3.229643   7.927287   8769.940430
# ...                  ...          ...        ...        ...           ...
# 2018-12-21  22396.339844  2408.550049  39.215000  50.764999  22871.740234
# 2018-12-24  21792.199219  2351.100098  37.037498  48.695000  22317.279297
# 2018-12-26  21712.529297  2346.580078  37.075001  49.450500  21857.730469
# 2018-12-27  22267.419922  2397.939941  38.959999  50.857498  22629.060547
# 2018-12-28  22981.330078  2472.889893  39.375000  52.480999  23213.609375
#
#                              Volume
#                   ^GSPC        AAPL       GOOG       ^DJI       ^GSPC
# Date
# 2009-01-02   902.989990   746015200  144961322  213700000  4048270000
# 2009-01-05   929.169983  1181608400  196293007  233760000  5413910000
# 2009-01-06   931.169983  1289310400  257971329  215410000  5392620000
# 2009-01-07   927.450012   753048800  180453860  266710000  4704940000
# 2009-01-08   905.729980   673500800  144567852  226620000  4991550000
# ...                 ...         ...        ...        ...         ...
# 2018-12-21  2465.379883   382978400   91920000  900510000  7657890000
# 2018-12-24  2400.560059   148676800   31806000  308420000  2613670000
# 2018-12-26  2363.120117   234330000   47466000  433080000  4249740000
# 2018-12-27  2442.500000   212468400   42196000  407940000  4139010000
# 2018-12-28  2498.770020   169165600   28296000  336510000  3728440000
#
# [2515 rows x 24 columns]

# %%
# Use just Close values
df = all_tickers['Close']

# %%
df
# Out:
#                  AAPL       GOOG          ^DJI        ^GSPC
# Date
# 2009-01-02   3.241071   8.003003   9034.690430   931.799988
# 2009-01-05   3.377857   8.170624   8952.889648   927.450012
# 2009-01-06   3.322143   8.320313   9015.099609   934.700012
# 2009-01-07   3.250357   8.020188   8769.700195   906.650024
# 2009-01-08   3.310714   8.099391   8742.459961   909.729980
# ...               ...        ...           ...          ...
# 2018-12-21  37.682499  48.977001  22445.369141  2416.620117
# 2018-12-24  36.707500  48.811001  21792.199219  2351.100098
# 2018-12-26  39.292500  51.973000  22878.449219  2467.699951
# 2018-12-27  39.037498  52.194000  23138.820312  2488.830078
# 2018-12-28  39.057499  51.854000  23062.400391  2485.739990
#
# [2515 rows x 4 columns]

# %%
fig, axs = plt.subplots(figsize=(16,9))
for ticker in df.columns: 
    ticker_data = df.loc[:,ticker]
    ticker_data = ticker_data / ticker_data.max()
    axs.plot(ticker_data.index, ticker_data, label=ticker)
axs.set_xlabel('Date')
axs.set_ylabel('Normalized closing price ($)')
axs.legend()
axs.grid(True)
plt.show()
